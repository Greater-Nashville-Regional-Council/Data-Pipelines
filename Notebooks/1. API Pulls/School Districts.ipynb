# %%
import pandas as pd
import numpy as np
import requests
#import io
import pickle
from collections import deque
from functools import reduce
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 150)
from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)
pd.options.mode.chained_assignment = None  # default='warn'
import sys
sys.path.append("../../../Functions and Dictionaries") # Adds higher directory to python modules path
import geodict
namestocommon = geodict.namestocommon
tofullcensus = geodict.tofullcensus
geotogeoid = geodict.geotogeoid
GNRC = geodict.GNRC
KY = geodict.KY
censusplaces = geodict.censusplaces

# %%
#functions
def percent(x, y):
        try:
            return ((x/y)*100)
        except ZeroDivisionError:
            return 0
def percentchange(x, y):
    try:
        return ((x - y)*100/y)
    except ZeroDivisionError:
        return 0
def realchange(x, y):
    return x-y

# %%
#to read in... rb is read bite
with open('api_keys.pkl', 'rb') as keys_file:
        keys_dict_2 = pickle.load(keys_file)
#create a variable that contains your api key
api_key = keys_dict_2['CENSUS']

# %%
url_str= 'https://api.census.gov/data/2021/acs/acs5?key='+api_key
predicates= {}
get_vars= ["NAME", 'B19013_001E']
predicates["get"]= ",". join(get_vars)
predicates["for"]= 'school district (elementary):*'
predicates["in"] = "state:47"
data= requests.get(url_str, params= predicates)
col_names = ['NAME', 'Median Household Income', 'GeoFIPS', 'PlaceFIPS']
data=pd.DataFrame(columns=col_names, data=data.json()[1:])
    
print('Your API call is complete')
# Out:
# Your API call is complete

# %%
data
# Out:
#                                                  NAME Median Household Income GeoFIPS PlaceFIPS
# 0               Alamo City School District, Tennessee                   51923      47     00030
# 1                      Athens City Schools, Tennessee                   42283      47     00120
# 2          Lakeland School System District, Tennessee                   99266      47     00154
# 3               Bells City School District, Tennessee                   55729      47     00210
# 4             Clinton City School District, Tennessee                   52991      47     00720
# 5   Dayton City Elementary School District, Tennessee                   40148      47     00930
# 6              Etowah City School District, Tennessee                   44958      47     01140
# 7         Franklin Special School District, Tennessee                   84140      47     01260
# 8          Lebanon Special School District, Tennessee                   57034      47     02370
# 9             Lexington City School System, Tennessee                   37302      47     02460
# 10         Manchester City School District, Tennessee                   47348      47     02610
# 11       Murfreesboro City School District, Tennessee                   66667      47     03150
# 12            Newport City School District, Tennessee                   33736      47     03210
# 13           Paris Special School District, Tennessee                   37139      47     03360
# 14                Rogersville City Schools, Tennessee                   41703      47     03660
# 15         Sweetwater City School District, Tennessee                   39605      47     04050
# 16                  Remainder of Tennessee, Tennessee                   58385      47     99999
