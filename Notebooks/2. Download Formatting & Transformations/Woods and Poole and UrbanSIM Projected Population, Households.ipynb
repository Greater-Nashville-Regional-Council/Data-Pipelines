# %% [markdown]
# ###### Imports and Settings

# %%
import pandas as pd
import numpy as np
import requests
from collections import deque
from functools import reduce
import pickle
import matplotlib.pyplot as plt
#pd.options.display.float_format = '{:,.0f}'.format
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 150)
pd.options.mode.chained_assignment = None  # default='warn'
import sys
sys.path.append("../../../Functions and Dictionaries/") # Adds higher directory to python modules path
import geodict
namestocommon = geodict.namestocommon
geotogeoid = geodict.geotogeoid
GNRC = geodict.GNRC
KY = geodict.KY
censusplaces = geodict.censusplaces
shorttnplaces = geodict.shorttnplaces
import sqlite3 as sq
#functions
def percentchange(x, y):
    try:
        return ((x - y)*100/y)
    except ZeroDivisionError:
        return 0
def realchange(x, y):
    return x-y
#calculate real and percent change between all columns for all possible time frames
def calculate_changes(df, columns, time_frames, years):
    for column in columns:
        for time_frame in time_frames:
            start_year, end_year = time_frame.split('-')
            df[f'{column} % Change', 'None', f'{time_frame}'] = percentchange(df[(column, int(end_year), 'None')], df[(column, int(start_year), 'None')])
            df[f'{column} Change', 'None', f'{time_frame}'] = (df[(column, int(end_year), 'None')] - df[(column, int(start_year), 'None')])

    return df
#generate all possible time frames from a list of years
def generate_time_frames(years):
    time_frames = []
    for i in range(len(years)-1):
        for j in range(i+1, len(years)):
            time_frames.append(f"{years[i]}-{years[j]}")
    return time_frames

# %%
#to read in... rb is read bite
with open('api_keys.pkl', 'rb') as keys_file:
        keys_dict_2 = pickle.load(keys_file)
#create a variable that contains your api key
api_key = keys_dict_2['CENSUS']

# %% [markdown]
# # Get 2020 PL population #

# %%
#2020 PL for households and population #s
#counties
url_str= 'https://api.census.gov/data/2020/dec/pl?key='+api_key
predicates= {}
get_vars= ["NAME", 'GEO_ID', 'P1_001N', 'H1_001N']
predicates["get"]= ",". join(get_vars)
predicates["for"]= "county:*"
predicates["in"]= "state:47" 
data = requests.get(url_str, params= predicates)
col_names = ['NAME', 'GEO_ID', 'Population', 'Households', 'StateFIPS', 'GeoFIPS']
df = pd.DataFrame(columns=col_names, data=data.json()[1:], dtype=str)
df = df.loc[df['GeoFIPS'].isin(GNRC)]
predicates= {}
get_vars= ["NAME", 'GEO_ID', 'P1_001N', 'H1_001N']
predicates["get"]= ",". join(get_vars)
predicates["for"]= "county:*"
predicates["in"]= "state:21" 
data = requests.get(url_str, params= predicates)                                                              
col_names = ['NAME', 'GEO_ID', 'Population', 'Households', 'StateFIPS', 'GeoFIPS']
kycos = pd.DataFrame(columns=col_names, data=data.json()[1:], dtype=str)
kycos = kycos.loc[kycos['GeoFIPS'].isin(KY)]
df = pd.concat([df, kycos], axis = 0)
#ky places call
predicates= {}
get_vars= ["NAME", 'GEO_ID', 'P1_001N', 'H1_001N']
predicates["get"]= ",". join(get_vars)
predicates["for"]= "place:*"
predicates["in"]= "state:21" 
data = requests.get(url_str, params= predicates)
col_names = ['NAME', 'GEO_ID', 'Population', 'Households', 'StateFIPS', 'GeoFIPS']
places=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype=str)
places=places.loc[places['GeoFIPS'].isin(shorttnplaces)]
df = pd.concat([df, places], axis = 0)
#places
predicates= {}
get_vars= ["NAME", 'GEO_ID', 'P1_001N', 'H1_001N']
predicates["get"]= ",". join(get_vars)
predicates["for"]= "place:*"
predicates["in"]= "state:47" 
data = requests.get(url_str, params= predicates)
col_names = ['NAME', 'GEO_ID', 'Population', 'Households', 'StateFIPS', 'GeoFIPS']
places=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype=str)
places=places.loc[places['GeoFIPS'].isin(shorttnplaces)]
df = pd.concat([df, places], axis = 0)
#state call
predicates= {}
get_vars= ["NAME", 'GEO_ID', 'P1_001N', 'H1_001N']
predicates["get"]= ",". join(get_vars)
predicates["for"]= "state:47"
data= requests.get(url_str, params= predicates)
col_names = ['NAME', 'GEO_ID', 'Population', 'Households', 'StateFIPS']
state=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype=str)
state['GeoFIPS'] = '0'
df = pd.concat([df, state], axis = 0)
#national call
predicates= {}
get_vars= ["NAME", 'GEO_ID', 'P1_001N', 'H1_001N']
predicates["get"]= ",". join(get_vars)
predicates["for"]= "us:*"
data= requests.get(url_str, params= predicates)
col_names = ['NAME', 'GEO_ID', 'Population', 'Households', 'StateFIPS']
national=pd.DataFrame(columns=col_names, data=data.json()[1:], dtype=str)
national['GeoFIPS'] = '0'
df = pd.concat([df, national], axis = 0)
savename = df
print('Okay Finished')
# Out:
# Okay Finished

# %%
pl2020 = savename

# %%
pl2020 = pl2020.drop(columns = ['StateFIPS', 'GeoFIPS', 'GEO_ID']).reset_index(drop = True)

# %%
pl2020.head()
# Out:
#                            NAME Population Households
# 0  Montgomery County, Tennessee     220069      85714
# 1  Rutherford County, Tennessee     341486     131216
# 2      Sumner County, Tennessee     196281      78995
# 3   Trousdale County, Tennessee      11615       3749
# 4  Williamson County, Tennessee     247726      91133

# %%
#set the index to the geography and transpose to aggregate regions, set the rest of the columns to float datatype
data = pl2020.set_index('NAME').transpose()
cols = data.columns
data[cols] = data[cols].astype(float)

# %%
GNRCCounties = [data['Stewart County, Tennessee'],data['Montgomery County, Tennessee'],
                data['Houston County, Tennessee'],data['Humphreys County, Tennessee'],
                data['Dickson County, Tennessee'],data['Cheatham County, Tennessee'],
                data['Robertson County, Tennessee'],data['Sumner County, Tennessee'],
                data['Davidson County, Tennessee'],data['Wilson County, Tennessee'],
                data['Trousdale County, Tennessee'],data['Williamson County, Tennessee'],
                data['Rutherford County, Tennessee']]
data['GNRC'] = sum(GNRCCounties)
GNRCCountiesAll = [data['Stewart County, Tennessee'],data['Montgomery County, Tennessee'],
                   data['Houston County, Tennessee'],data['Humphreys County, Tennessee'],
                   data['Dickson County, Tennessee'],data['Cheatham County, Tennessee'],
                   data['Robertson County, Tennessee'],data['Sumner County, Tennessee'],
                   data['Davidson County, Tennessee'],data['Wilson County, Tennessee'],
                   data['Trousdale County, Tennessee'],data['Williamson County, Tennessee'],
                   data['Rutherford County, Tennessee'],data['Maury County, Tennessee']]
data['GNRC Region'] = sum(GNRCCountiesAll)
MPOCounties = [data['Robertson County, Tennessee'],data['Sumner County, Tennessee'],
               data['Davidson County, Tennessee'],data['Wilson County, Tennessee'],
               data['Williamson County, Tennessee'],data['Rutherford County, Tennessee'],
               data['Maury County, Tennessee']]
data['MPO'] = sum(MPOCounties)
RuthInc = [data['Eagleville city, Tennessee'],data['La Vergne city, Tennessee'],
           data['Murfreesboro city, Tennessee'],data['Smyrna town, Tennessee']]
data['Rutherford Incorporated'] = sum(RuthInc)
data['Rutherford Unincorporated'] = data['Rutherford County, Tennessee'] - data['Rutherford Incorporated']
WilsonInc = [data['Lebanon city, Tennessee'],data['Mount Juliet city, Tennessee'],
             data['Watertown city, Tennessee']]
data['Wilson Incorporated'] = sum(WilsonInc)
data['Wilson Unincorporated'] = data['Wilson County, Tennessee'] - data['Wilson Incorporated']
CheathInc = [data['Ashland City town, Tennessee'],data['Kingston Springs town, Tennessee'],
             data['Pegram town, Tennessee'],data['Pleasant View city, Tennessee']]
data['Cheatham Incorporated'] = sum(CheathInc)
data['Cheatham Unincorporated'] = data['Cheatham County, Tennessee'] - data['Cheatham Incorporated']
DicksInc = [data['Burns town, Tennessee'],data['Charlotte town, Tennessee'],
            data['Dickson city, Tennessee'],data['Slayden town, Tennessee'],
            data['Vanleer town, Tennessee'],data['White Bluff town, Tennessee']]
data['Dickson Incorporated'] = sum(DicksInc)
data['Dickson Unincorporated'] = data['Dickson County, Tennessee'] - data['Dickson Incorporated']
HumphInc = [data['McEwen city, Tennessee'],data['New Johnsonville city, Tennessee'],
            data['Waverly city, Tennessee']]
data['Humphreys Incorporated'] = sum(HumphInc)
data['Humphreys Unincorporated'] = data['Humphreys County, Tennessee'] - data['Humphreys Incorporated']
data['Montgomery Incorporated'] = data['Clarksville city, Tennessee']
data['Montgomery Unincorporated'] = data['Montgomery County, Tennessee'] - data['Montgomery Incorporated']

# %%
#transpose back and reset the index
pl2020 = data.transpose().reset_index()

# %%
#check that data is ready to join
pl2020.head()
# Out:
#                            NAME  Population  Households
# 0  Montgomery County, Tennessee    220069.0     85714.0
# 1  Rutherford County, Tennessee    341486.0    131216.0
# 2      Sumner County, Tennessee    196281.0     78995.0
# 3   Trousdale County, Tennessee     11615.0      3749.0
# 4  Williamson County, Tennessee    247726.0     91133.0

# %% [markdown]
# ### Households

# %%
#households
data = pd.read_csv('../../Data Downloads/WoodsPooleUrbanSIM_HouseholdsProjections_2017Base.csv')

# %%
#merge pl2020 and replace 2020 WP # with Census #
real2020 = pl2020.drop(columns = 'Population')
data = data.merge(real2020, on = 'NAME')
data['2020'] = data['Households']
data = data.drop(columns = ['Households', 'GEO_ID'])

# %%
data.head()
# Out:
#                           NAME    2017      2020    2025    2035    2045
# 0   Cheatham County, Tennessee   14671   16785.0   17101   19514   22019
# 1   Davidson County, Tennessee  273497  328309.0  297798  315192  332379
# 2    Dickson County, Tennessee   19032   22551.0   21596   23868   26141
# 3    Houston County, Tennessee    2999    3936.0    3444    3840    4230
# 4  Humphreys County, Tennessee    7064    8849.0    7622    7949    8247

# %%
data['NAME'].value_counts()
# Out:
# Cheatham County, Tennessee                                         1
# Erin city, Tennessee                                               1
# New Johnsonville city, Tennessee                                   1
# Nashville-Davidson metropolitan government (balance), Tennessee    1
# Murfreesboro city, Tennessee                                       1
# Mount Pleasant city, Tennessee                                     1
# Mount Juliet city, Tennessee                                       1
# Mitchellville city, Tennessee                                      1
# Millersville city, Tennessee                                       1
# McEwen city, Tennessee                                             1
# Lebanon city, Tennessee                                            1
# La Vergne city, Tennessee                                          1
# Kingston Springs town, Tennessee                                   1
# Hendersonville city, Tennessee                                     1
# Greenbrier town, Tennessee                                         1
# Goodlettsville city, Tennessee                                     1
# Gallatin city, Tennessee                                           1
# Franklin city, Tennessee                                           1
# Forest Hills city, Tennessee                                       1
# Nolensville town, Tennessee                                        1
# Oak Hill city, Tennessee                                           1
# Pegram town, Tennessee                                             1
# Vanleer town, Tennessee                                            1
# MPO                                                                1
# GNRC                                                               1
# White House city, Tennessee                                        1
# White Bluff town, Tennessee                                        1
# Westmoreland town, Tennessee                                       1
# Waverly city, Tennessee                                            1
# Watertown city, Tennessee                                          1
# Thompson's Station town, Tennessee                                 1
# Pleasant View city, Tennessee                                      1
# Tennessee Ridge town, Tennessee                                    1
# Springfield city, Tennessee                                        1
# Spring Hill city, Tennessee                                        1
# Smyrna town, Tennessee                                             1
# Slayden town, Tennessee                                            1
# Ridgetop city, Tennessee                                           1
# Portland city, Tennessee                                           1
# Fairview city, Tennessee                                           1
# Eagleville city, Tennessee                                         1
# Davidson County, Tennessee                                         1
# Dover city, Tennessee                                              1
# Rutherford Incorporated                                            1
# Montgomery Incorporated                                            1
# Humphreys Incorporated                                             1
# Dickson Incorporated                                               1
# Cheatham Incorporated                                              1
# Trousdale County, Tennessee                                        1
# Wilson County, Tennessee                                           1
# Williamson County, Tennessee                                       1
# Sumner County, Tennessee                                           1
# Stewart County, Tennessee                                          1
# Rutherford County, Tennessee                                       1
# Robertson County, Tennessee                                        1
# Montgomery County, Tennessee                                       1
# Maury County, Tennessee                                            1
# Humphreys County, Tennessee                                        1
# Houston County, Tennessee                                          1
# Dickson County, Tennessee                                          1
# Wilson Incorporated                                                1
# Cheatham Unincorporated                                            1
# Dickson Unincorporated                                             1
# Cedar Hill city, Tennessee                                         1
# Dickson city, Tennessee                                            1
# Cumberland City town, Tennessee                                    1
# Cross Plains city, Tennessee                                       1
# Coopertown town, Tennessee                                         1
# Columbia city, Tennessee                                           1
# Clarksville city, Tennessee                                        1
# Charlotte town, Tennessee                                          1
# Burns town, Tennessee                                              1
# Humphreys Unincorporated                                           1
# Brentwood city, Tennessee                                          1
# Berry Hill city, Tennessee                                         1
# Belle Meade city, Tennessee                                        1
# Ashland City town, Tennessee                                       1
# Adams city, Tennessee                                              1
# Wilson Unincorporated                                              1
# Rutherford Unincorporated                                          1
# GNRC Region                                                        1
# Name: NAME, dtype: int64

# %%
hhsuff = data.set_index('NAME').add_prefix('Households ')

# %%
hhsuff.head()
# Out:
#                              Households 2017  Households 2020  Households 2025  Households 2035  Households 2045
# NAME
# Cheatham County, Tennessee             14671          16785.0            17101            19514            22019
# Davidson County, Tennessee            273497         328309.0           297798           315192           332379
# Dickson County, Tennessee              19032          22551.0            21596            23868            26141
# Houston County, Tennessee               2999           3936.0             3444             3840             4230
# Humphreys County, Tennessee             7064           8849.0             7622             7949             8247

# %%
cols = data.columns
#hhproj = data.reset_index(drop = False)
hhproj = data.melt(id_vars = 'NAME', var_name = 'Year', value_name = 'Households')#, values = cols)
hhproj.head()
# Out:
#                           NAME  Year  Households
# 0   Cheatham County, Tennessee  2017     14671.0
# 1   Davidson County, Tennessee  2017    273497.0
# 2    Dickson County, Tennessee  2017     19032.0
# 3    Houston County, Tennessee  2017      2999.0
# 4  Humphreys County, Tennessee  2017      7064.0

# %%
#populations
data = pd.read_csv('../../Data Downloads/WoodsPooleUrbanSIM_PopulationProjections_2017Base.csv')
data.head()
# Out:
#                           NAME            GEO_ID    2017    2020    2025    2035    2045  Unnamed: 7
# 0   Cheatham County, Tennessee    0500000US47021   39714   41392   44245   49849   54774         NaN
# 1   Davidson County, Tennessee    0500000US47037  678322  699326  734235  798722  848072         NaN
# 2    Dickson County, Tennessee  1600000US4720620   51341   53116   56089   61698   66221         NaN
# 3    Houston County, Tennessee    0500000US47083    8118    8440    8862    9643   10243         NaN
# 4  Humphreys County, Tennessee    0500000US47085   18218   18586   19071   19833   20150         NaN

# %%
#merge pl2020 and replace 2020 WP # with Census #
real2020 = pl2020.drop(columns = 'Households')
data = data.merge(real2020, on = 'NAME')
data['2020'] = data['Population']
data = data.drop(columns = ['Population', 'GEO_ID'])

# %%
popsuff = data.set_index('NAME').add_prefix('Population ')

# %%
cols = data.columns
#hhproj = data.reset_index(drop = False)
popproj = data.melt(id_vars = 'NAME', var_name = 'Year', value_name = 'Population')#, values = cols)
popproj.head(3)
# Out:
#                          NAME  Year  Population
# 0  Cheatham County, Tennessee  2017     39714.0
# 1  Davidson County, Tennessee  2017    678322.0
# 2   Dickson County, Tennessee  2017     51341.0

# %%
data = popproj.merge(hhproj, on = ['NAME', 'Year'])
data
# Out:
#                                                   NAME  Year  Population  Households
# 0                           Cheatham County, Tennessee  2017     39714.0     14671.0
# 1                           Davidson County, Tennessee  2017    678322.0    273497.0
# 2                            Dickson County, Tennessee  2017     51341.0     19032.0
# 3                            Houston County, Tennessee  2017      8118.0      2999.0
# 4                          Humphreys County, Tennessee  2017     18218.0      7064.0
# 5                              Maury County, Tennessee  2017     87606.0     33332.0
# 6                         Montgomery County, Tennessee  2017    192120.0     68904.0
# 7                          Robertson County, Tennessee  2017     68575.0     25065.0
# 8                         Rutherford County, Tennessee  2017    298456.0    106673.0
# 9                            Stewart County, Tennessee  2017     13248.0      5315.0
# 10                            Sumner County, Tennessee  2017    175730.0     64600.0
# 11                        Williamson County, Tennessee  2017    212161.0     73160.0
# 12                            Wilson County, Tennessee  2017    128874.0     47213.0
# 13                         Trousdale County, Tennessee  2017      8773.0      2944.0
# 14                               Cheatham Incorporated  2017     14392.0      5489.0
# 15                                Dickson Incorporated  2017     21657.0      8747.0
# 16                              Humphreys Incorporated  2017      7545.0      3243.0
# 17                             Montgomery Incorporated  2017    141695.0     53533.0
# 18                             Rutherford Incorporated  2017    205865.0     77230.0
# 19                                 Wilson Incorporated  2017     64880.0     24427.0
# 20                             Cheatham Unincorporated  2017     24296.0      9182.0
# 21                              Dickson Unincorporated  2017     27346.0     10285.0
# 22                            Humphreys Unincorporated  2017      9647.0      3821.0
# 23                           Rutherford Unincorporated  2017     84366.0     29443.0
# 24                               Wilson Unincorporated  2017     60171.0     22786.0
# 25                               Adams city, Tennessee  2017       728.0       228.0
# 26                        Ashland City town, Tennessee  2017      4701.0      2070.0
# 27                         Belle Meade city, Tennessee  2017      2615.0      1021.0
# 28                          Berry Hill city, Tennessee  2017       886.0       536.0
# 29                           Brentwood city, Tennessee  2017     39849.0     13277.0
# 30                               Burns town, Tennessee  2017      1610.0       602.0
# 31                          Cedar Hill city, Tennessee  2017       294.0       108.0
# 32                           Charlotte town, Tennessee  2017      1247.0       507.0
# 33                         Clarksville city, Tennessee  2017    141695.0     53533.0
# 34                            Columbia city, Tennessee  2017     37473.0     14954.0
# 35                          Coopertown town, Tennessee  2017      4249.0      1452.0
# 36                        Cross Plains city, Tennessee  2017      1908.0       667.0
# 37                     Cumberland City town, Tennessee  2017       406.0       180.0
# 38                             Dickson city, Tennessee  2017     14453.0      5980.0
# 39                               Dover city, Tennessee  2017      1743.0       718.0
# 40                          Eagleville city, Tennessee  2017       788.0       300.0
# 41                                Erin city, Tennessee  2017      1087.0       463.0
# 42                            Fairview city, Tennessee  2017      8590.0      3002.0
# 43                        Forest Hills city, Tennessee  2017      4922.0      1851.0
# 44                            Franklin city, Tennessee  2017     74514.0     28426.0
# 45                            Gallatin city, Tennessee  2017     33637.0     13319.0
# 46                      Goodlettsville city, Tennessee  2017     16715.0      7087.0
# 47                          Greenbrier town, Tennessee  2017      6763.0      2505.0
# 48                      Hendersonville city, Tennessee  2017     54634.0     21298.0
# 49                    Kingston Springs town, Tennessee  2017      2889.0      1054.0
# 50                           La Vergne city, Tennessee  2017     34904.0     11036.0
# 51                             Lebanon city, Tennessee  2017     30343.0     11783.0
# 52                              McEwen city, Tennessee  2017      1869.0       741.0
# 53                        Millersville city, Tennessee  2017      6893.0      2738.0
# 54                       Mitchellville city, Tennessee  2017       163.0        60.0
# 55                        Mount Juliet city, Tennessee  2017     32917.0     12023.0
# 56                      Mount Pleasant city, Tennessee  2017      4721.0      1958.0
# 57                        Murfreesboro city, Tennessee  2017    122320.0     48133.0
# 58   Nashville-Davidson metropolitan government (ba...  2017    615511.0    263680.0
# 59                    New Johnsonville city, Tennessee  2017      1959.0       791.0
# 60                         Nolensville town, Tennessee  2017      7656.0      2305.0
# 61                            Oak Hill city, Tennessee  2017      4469.0      1727.0
# 62                              Pegram town, Tennessee  2017      2391.0       883.0
# 63                       Pleasant View city, Tennessee  2017      4287.0      1436.0
# 64                            Portland city, Tennessee  2017     13059.0      4574.0
# 65                            Ridgetop city, Tennessee  2017      2138.0       839.0
# 66                             Slayden town, Tennessee  2017       236.0        84.0
# 67                              Smyrna town, Tennessee  2017     47868.0     17767.0
# 68                         Spring Hill city, Tennessee  2017     35609.0     11822.0
# 69                         Springfield city, Tennessee  2017     15815.0      6371.0
# 70                     Tennessee Ridge town, Tennessee  2017      1393.0       611.0
# 71                  Thompson's Station town, Tennessee  2017      4489.0      1446.0
# 72                             Vanleer town, Tennessee  2017       379.0       149.0
# 73                           Watertown city, Tennessee  2017      1554.0       600.0
# 74                             Waverly city, Tennessee  2017      3717.0      1711.0
# 75                        Westmoreland town, Tennessee  2017      2431.0       919.0
# 76                         White Bluff town, Tennessee  2017      3733.0      1426.0
# 77                         White House city, Tennessee  2017     12392.0      4305.0
# 78                                                GNRC  2017   1893650.0    711137.0
# 79                                                 MPO  2017   1649724.0    623540.0
# 80                                         GNRC Region  2017   1981256.0    744469.0
# 81                          Cheatham County, Tennessee  2020     41072.0     16785.0
# 82                          Davidson County, Tennessee  2020    715884.0    328309.0
# 83                           Dickson County, Tennessee  2020     54315.0     22551.0
# 84                           Houston County, Tennessee  2020      8283.0      3936.0
# 85                         Humphreys County, Tennessee  2020     18990.0      8849.0
# 86                             Maury County, Tennessee  2020    100974.0     43143.0
# 87                        Montgomery County, Tennessee  2020    220069.0     85714.0
# 88                         Robertson County, Tennessee  2020     72803.0     28459.0
# 89                        Rutherford County, Tennessee  2020    341486.0    131216.0
# 90                           Stewart County, Tennessee  2020     13657.0      6669.0
# 91                            Sumner County, Tennessee  2020    196281.0     78995.0
# 92                        Williamson County, Tennessee  2020    247726.0     91133.0
# 93                            Wilson County, Tennessee  2020    147737.0     58152.0
# 94                         Trousdale County, Tennessee  2020     11615.0      3749.0
# 95                               Cheatham Incorporated  2020     14896.0      6235.0
# 96                                Dickson Incorporated  2020     23693.0     10039.0
# 97                              Humphreys Incorporated  2020      7744.0      3512.0
# 98                             Montgomery Incorporated  2020    166722.0     65752.0
# 99                             Rutherford Incorporated  2020    245371.0     96534.0
# 100                                Wilson Incorporated  2020     79273.0     31448.0
# 101                            Cheatham Unincorporated  2020     26176.0     10550.0
# 102                             Dickson Unincorporated  2020     30622.0     12512.0
# 103                           Humphreys Unincorporated  2020     11246.0      5337.0
# 104                          Rutherford Unincorporated  2020     96115.0     34682.0
# 105                              Wilson Unincorporated  2020     68464.0     26704.0
# 106                              Adams city, Tennessee  2020       624.0       250.0
# 107                       Ashland City town, Tennessee  2020      5193.0      2311.0
# 108                        Belle Meade city, Tennessee  2020      2901.0      1130.0
# 109                         Berry Hill city, Tennessee  2020      2112.0      1657.0
# 110                          Brentwood city, Tennessee  2020     45373.0     15279.0
# 111                              Burns town, Tennessee  2020      1573.0       675.0
# 112                         Cedar Hill city, Tennessee  2020       301.0       123.0
# 113                          Charlotte town, Tennessee  2020      1656.0       572.0
# 114                        Clarksville city, Tennessee  2020    166722.0     65752.0
# 115                           Columbia city, Tennessee  2020     41690.0     18335.0
# 116                         Coopertown town, Tennessee  2020      4480.0      1665.0
# 117                       Cross Plains city, Tennessee  2020      1789.0       701.0
# 118                    Cumberland City town, Tennessee  2020       305.0       164.0
# 119                            Dickson city, Tennessee  2020     16058.0      6936.0
# 120                              Dover city, Tennessee  2020      1826.0       746.0
# 121                         Eagleville city, Tennessee  2020       813.0       326.0
# 122                               Erin city, Tennessee  2020      1224.0       534.0
# 123                           Fairview city, Tennessee  2020      9357.0      3554.0
# 124                       Forest Hills city, Tennessee  2020      5038.0      1894.0
# 125                           Franklin city, Tennessee  2020     83454.0     34720.0
# 126                           Gallatin city, Tennessee  2020     44431.0     19201.0
# 127                     Goodlettsville city, Tennessee  2020     17789.0      7784.0
# 128                         Greenbrier town, Tennessee  2020      6898.0      2624.0
# 129                     Hendersonville city, Tennessee  2020     61753.0     24963.0
# 130                   Kingston Springs town, Tennessee  2020      2824.0      1148.0
# 131                          La Vergne city, Tennessee  2020     38719.0     12890.0
# 132                            Lebanon city, Tennessee  2020     38431.0     15734.0
# 133                             McEwen city, Tennessee  2020      1643.0       807.0
# 134                       Millersville city, Tennessee  2020      6299.0      2580.0
# 135                      Mitchellville city, Tennessee  2020       163.0        74.0
# 136                       Mount Juliet city, Tennessee  2020     39289.0     15090.0
# 137                     Mount Pleasant city, Tennessee  2020      4784.0      2124.0
# 138                       Murfreesboro city, Tennessee  2020    152769.0     62905.0
# 139  Nashville-Davidson metropolitan government (ba...  2020    689447.0    316363.0
# 140                   New Johnsonville city, Tennessee  2020      1804.0       790.0
# 141                        Nolensville town, Tennessee  2020     13829.0      4216.0
# 142                           Oak Hill city, Tennessee  2020      4891.0      1874.0
# 143                             Pegram town, Tennessee  2020      2072.0       849.0
# 144                      Pleasant View city, Tennessee  2020      4807.0      1927.0
# 145                           Portland city, Tennessee  2020     13156.0      5084.0
# 146                           Ridgetop city, Tennessee  2020      2155.0       898.0
# 147                            Slayden town, Tennessee  2020       170.0        93.0
# 148                             Smyrna town, Tennessee  2020     53070.0     20413.0
# 149                        Spring Hill city, Tennessee  2020     50005.0     17939.0
# 150                        Springfield city, Tennessee  2020     18782.0      7351.0
# 151                    Tennessee Ridge town, Tennessee  2020      1332.0       599.0
# 152                 Thompson's Station town, Tennessee  2020      7485.0      2690.0
# 153                            Vanleer town, Tennessee  2020       374.0       166.0
# 154                          Watertown city, Tennessee  2020      1553.0       624.0
# 155                            Waverly city, Tennessee  2020      4297.0      1915.0
# 156                       Westmoreland town, Tennessee  2020      2718.0      1070.0
# 157                        White Bluff town, Tennessee  2020      3862.0      1597.0
# 158                        White House city, Tennessee  2020     12982.0      5039.0
# 159                                               GNRC  2020   2089918.0    864517.0
# 160                                                MPO  2020   1822891.0    759407.0
# 161                                        GNRC Region  2020   2190892.0    907660.0
# 162                         Cheatham County, Tennessee  2025     44245.0     17101.0
# 163                         Davidson County, Tennessee  2025    734235.0    297798.0
# 164                          Dickson County, Tennessee  2025     56089.0     21596.0
# 165                          Houston County, Tennessee  2025      8862.0      3444.0
# 166                        Humphreys County, Tennessee  2025     19071.0      7622.0
# 167                            Maury County, Tennessee  2025     96608.0     37634.0
# 168                       Montgomery County, Tennessee  2025    231501.0     86383.0
# 169                        Robertson County, Tennessee  2025     78095.0     29434.0
# 170                       Rutherford County, Tennessee  2025    363610.0    132670.0
# 171                          Stewart County, Tennessee  2025     14195.0      5860.0
# 172                           Sumner County, Tennessee  2025    204290.0     77435.0
# 173                       Williamson County, Tennessee  2025    285527.0    102311.0
# 174                           Wilson County, Tennessee  2025    160363.0     60268.0
# 175                        Trousdale County, Tennessee  2025      9280.0      3286.0
# 176                              Cheatham Incorporated  2025     17795.0      6799.0
# 177                               Dickson Incorporated  2025     24463.0      9875.0
# 178                             Humphreys Incorporated  2025      7961.0      3440.0
# 179                            Montgomery Incorporated  2025    169770.0     64535.0
# 180                            Rutherford Incorporated  2025    244176.0     91781.0
# 181                                Wilson Incorporated  2025     75057.0     28732.0
# 182                            Cheatham Unincorporated  2025     27275.0     10302.0
# 183                             Dickson Unincorporated  2025     31189.0     11721.0
# 184                           Humphreys Unincorporated  2025     10538.0      4182.0
# 185                          Rutherford Unincorporated  2025    116753.0     40889.0
# 186                              Wilson Unincorporated  2025     84315.0     31536.0
# 187                              Adams city, Tennessee  2025       801.0       249.0
# 188                       Ashland City town, Tennessee  2025      6315.0      2737.0
# 189                        Belle Meade city, Tennessee  2025      2790.0      1081.0
# 190                         Berry Hill city, Tennessee  2025      1280.0       726.0
# 191                          Brentwood city, Tennessee  2025     43876.0     14596.0
# 192                              Burns town, Tennessee  2025      1798.0       670.0
# 193                         Cedar Hill city, Tennessee  2025       325.0       119.0
# 194                          Charlotte town, Tennessee  2025      1418.0       592.0
# 195                        Clarksville city, Tennessee  2025    169770.0     64535.0
# 196                           Columbia city, Tennessee  2025     43898.0     17564.0
# 197                         Coopertown town, Tennessee  2025      4811.0      1629.0
# 198                       Cross Plains city, Tennessee  2025      1995.0       699.0
# 199                    Cumberland City town, Tennessee  2025       413.0       184.0
# 200                            Dickson city, Tennessee  2025     16431.0      6774.0
# 201                              Dover city, Tennessee  2025      1827.0       756.0
# 202                         Eagleville city, Tennessee  2025       954.0       365.0
# 203                               Erin city, Tennessee  2025      1214.0       515.0
# 204                           Fairview city, Tennessee  2025     12194.0      4321.0
# 205                       Forest Hills city, Tennessee  2025      5637.0      2113.0
# 206                           Franklin city, Tennessee  2025     87923.0     33657.0
# 207                           Gallatin city, Tennessee  2025     39404.0     15708.0
# 208                     Goodlettsville city, Tennessee  2025     19639.0      8251.0
# 209                         Greenbrier town, Tennessee  2025      7529.0      2812.0
# 210                     Hendersonville city, Tennessee  2025     62769.0     24433.0
# 211                   Kingston Springs town, Tennessee  2025      3359.0      1222.0
# 212                          La Vergne city, Tennessee  2025     39944.0     12832.0
# 213                            Lebanon city, Tennessee  2025     39220.0     15449.0
# 214                             McEwen city, Tennessee  2025      1963.0       782.0
# 215                       Millersville city, Tennessee  2025      7754.0      3086.0
# 216                      Mitchellville city, Tennessee  2025       192.0        74.0
# 217                       Mount Juliet city, Tennessee  2025     33995.0     12572.0
# 218                     Mount Pleasant city, Tennessee  2025      4826.0      2003.0
# 219                       Murfreesboro city, Tennessee  2025    152467.0     59707.0
# 220  Nashville-Davidson metropolitan government (ba...  2025    668984.0    286662.0
# 221                   New Johnsonville city, Tennessee  2025      2062.0       836.0
# 222                        Nolensville town, Tennessee  2025     12358.0      4033.0
# 223                           Oak Hill city, Tennessee  2025      4899.0      1892.0
# 224                             Pegram town, Tennessee  2025      2956.0      1094.0
# 225                      Pleasant View city, Tennessee  2025      5031.0      1695.0
# 226                           Portland city, Tennessee  2025     14467.0      5115.0
# 227                           Ridgetop city, Tennessee  2025      2406.0       947.0
# 228                            Slayden town, Tennessee  2025       246.0        87.0
# 229                             Smyrna town, Tennessee  2025     50874.0     18898.0
# 230                        Spring Hill city, Tennessee  2025     40970.0     13829.0
# 231                        Springfield city, Tennessee  2025     21126.0      8467.0
# 232                    Tennessee Ridge town, Tennessee  2025      1714.0       745.0
# 233                 Thompson's Station town, Tennessee  2025      3997.0      1385.0
# 234                            Vanleer town, Tennessee  2025       409.0       158.0
# 235                          Watertown city, Tennessee  2025      1742.0       678.0
# 236                            Waverly city, Tennessee  2025      3936.0      1822.0
# 237                       Westmoreland town, Tennessee  2025      3104.0      1196.0
# 238                        White Bluff town, Tennessee  2025      4163.0      1596.0
# 239                        White House city, Tennessee  2025     15449.0      5394.0
# 240                                               GNRC  2025   2209363.0    845208.0
# 241                                                MPO  2025   1922728.0    737550.0
# 242                                        GNRC Region  2025   2305971.0    882842.0
# 243                         Cheatham County, Tennessee  2035     49849.0     19514.0
# 244                         Davidson County, Tennessee  2035    798722.0    315192.0
# 245                          Dickson County, Tennessee  2035     61698.0     23868.0
# 246                          Houston County, Tennessee  2035      9643.0      3840.0
# 247                        Humphreys County, Tennessee  2035     19833.0      7949.0
# 248                            Maury County, Tennessee  2035    107493.0     41564.0
# 249                       Montgomery County, Tennessee  2035    286262.0    107198.0
# 250                        Robertson County, Tennessee  2035     90357.0     33903.0
# 251                       Rutherford County, Tennessee  2035    455888.0    163640.0
# 252                          Stewart County, Tennessee  2035     15251.0      6279.0
# 253                           Sumner County, Tennessee  2035    242234.0     91424.0
# 254                       Williamson County, Tennessee  2035    402255.0    143419.0
# 255                           Wilson County, Tennessee  2035    206139.0     76650.0
# 256                        Trousdale County, Tennessee  2035      9860.0      3567.0
# 257                              Cheatham Incorporated  2035     21248.0      8171.0
# 258                               Dickson Incorporated  2035     26609.0     10802.0
# 259                             Humphreys Incorporated  2035      8260.0      3571.0
# 260                            Montgomery Incorporated  2035    195661.0     74855.0
# 261                            Rutherford Incorporated  2035    281677.0    106352.0
# 262                                Wilson Incorporated  2035     86318.0     33353.0
# 263                            Cheatham Unincorporated  2035     30125.0     11343.0
# 264                             Dickson Unincorporated  2035     34746.0     13066.0
# 265                           Humphreys Unincorporated  2035     11024.0      4378.0
# 266                          Rutherford Unincorporated  2035    163414.0     57288.0
# 267                              Wilson Unincorporated  2035    116572.0     43297.0
# 268                              Adams city, Tennessee  2035       876.0       274.0
# 269                       Ashland City town, Tennessee  2035      7850.0      3428.0
# 270                        Belle Meade city, Tennessee  2035      2875.0      1114.0
# 271                         Berry Hill city, Tennessee  2035      1702.0       913.0
# 272                          Brentwood city, Tennessee  2035     48343.0     16051.0
# 273                              Burns town, Tennessee  2035      1958.0       725.0
# 274                         Cedar Hill city, Tennessee  2035       354.0       130.0
# 275                          Charlotte town, Tennessee  2035      1551.0       655.0
# 276                        Clarksville city, Tennessee  2035    195661.0     74855.0
# 277                           Columbia city, Tennessee  2035     49468.0     19828.0
# 278                         Coopertown town, Tennessee  2035      5466.0      1859.0
# 279                       Cross Plains city, Tennessee  2035      2131.0       746.0
# 280                    Cumberland City town, Tennessee  2035       416.0       186.0
# 281                            Dickson city, Tennessee  2035     17934.0      7444.0
# 282                              Dover city, Tennessee  2035      1888.0       783.0
# 283                         Eagleville city, Tennessee  2035      1294.0       487.0
# 284                               Erin city, Tennessee  2035      1336.0       566.0
# 285                           Fairview city, Tennessee  2035     18667.0      6706.0
# 286                       Forest Hills city, Tennessee  2035      6134.0      2282.0
# 287                           Franklin city, Tennessee  2035    102761.0     39205.0
# 288                           Gallatin city, Tennessee  2035     45303.0     18191.0
# 289                     Goodlettsville city, Tennessee  2035     21861.0      9143.0
# 290                         Greenbrier town, Tennessee  2035      8313.0      3115.0
# 291                     Hendersonville city, Tennessee  2035     70090.0     27346.0
# 292                   Kingston Springs town, Tennessee  2035      3845.0      1393.0
# 293                          La Vergne city, Tennessee  2035     44915.0     14622.0
# 294                            Lebanon city, Tennessee  2035     45861.0     18202.0
# 295                             McEwen city, Tennessee  2035      2039.0       811.0
# 296                       Millersville city, Tennessee  2035      8557.0      3398.0
# 297                      Mitchellville city, Tennessee  2035       241.0        93.0
# 298                       Mount Juliet city, Tennessee  2035     38425.0     14361.0
# 299                     Mount Pleasant city, Tennessee  2035      4942.0      2053.0
# 300                       Murfreesboro city, Tennessee  2035    180832.0     70897.0
# 301  Nashville-Davidson metropolitan government (ba...  2035    707626.0    303186.0
# 302                   New Johnsonville city, Tennessee  2035      2140.0       867.0
# 303                        Nolensville town, Tennessee  2035     18844.0      6435.0
# 304                           Oak Hill city, Tennessee  2035      5207.0      2013.0
# 305                             Pegram town, Tennessee  2035      3593.0      1340.0
# 306                      Pleasant View city, Tennessee  2035      5810.0      1952.0
# 307                           Portland city, Tennessee  2035     15918.0      5688.0
# 308                           Ridgetop city, Tennessee  2035      2677.0      1040.0
# 309                            Slayden town, Tennessee  2035       258.0        92.0
# 310                             Smyrna town, Tennessee  2035     54800.0     20399.0
# 311                        Spring Hill city, Tennessee  2035     46543.0     15931.0
# 312                        Springfield city, Tennessee  2035     26241.0     10554.0
# 313                    Tennessee Ridge town, Tennessee  2035      1980.0       854.0
# 314                 Thompson's Station town, Tennessee  2035      9943.0      3584.0
# 315                            Vanleer town, Tennessee  2035       420.0       163.0
# 316                          Watertown city, Tennessee  2035      1917.0       750.0
# 317                            Waverly city, Tennessee  2035      4081.0      1893.0
# 318                       Westmoreland town, Tennessee  2035      3864.0      1503.0
# 319                        White Bluff town, Tennessee  2035      4490.0      1725.0
# 320                        White House city, Tennessee  2035     18177.0      6413.0
# 321                                               GNRC  2035   2647991.0    996443.0
# 322                                                MPO  2035   2303088.0    865792.0
# 323                                        GNRC Region  2035   2755484.0   1038007.0
# 324                         Cheatham County, Tennessee  2045     54774.0     22019.0
# 325                         Davidson County, Tennessee  2045    848072.0    332379.0
# 326                          Dickson County, Tennessee  2045     66221.0     26141.0
# 327                          Houston County, Tennessee  2045     10243.0      4230.0
# 328                        Humphreys County, Tennessee  2045     20150.0      8247.0
# 329                            Maury County, Tennessee  2045    116676.0     45587.0
# 330                       Montgomery County, Tennessee  2045    343980.0    130932.0
# 331                        Robertson County, Tennessee  2045    101888.0     38621.0
# 332                       Rutherford County, Tennessee  2045    555516.0    199112.0
# 333                          Stewart County, Tennessee  2045     15997.0      6684.0
# 334                           Sumner County, Tennessee  2045    279686.0    106639.0
# 335                       Williamson County, Tennessee  2045    548266.0    196361.0
# 336                           Wilson County, Tennessee  2045    257285.0     96057.0
# 337                        Trousdale County, Tennessee  2045     10267.0      3844.0
# 338                              Cheatham Incorporated  2045     24844.0      9550.0
# 339                               Dickson Incorporated  2045     28839.0     11735.0
# 340                             Humphreys Incorporated  2045      8481.0      3665.0
# 341                            Montgomery Incorporated  2045    218730.0     84382.0
# 342                            Rutherford Incorporated  2045    312063.0    118617.0
# 343                                Wilson Incorporated  2045     96563.0     37542.0
# 344                            Cheatham Unincorporated  2045     33171.0     12469.0
# 345                             Dickson Unincorporated  2045     38356.0     14406.0
# 346                           Humphreys Unincorporated  2045     11517.0      4582.0
# 347                          Rutherford Unincorporated  2045    229342.0     80495.0
# 348                              Wilson Unincorporated  2045    157758.0     58515.0
# 349                              Adams city, Tennessee  2045       995.0       309.0
# 350                       Ashland City town, Tennessee  2045      9431.0      4101.0
# 351                        Belle Meade city, Tennessee  2045      2959.0      1146.0
# 352                         Berry Hill city, Tennessee  2045      2242.0      1171.0
# 353                          Brentwood city, Tennessee  2045     52655.0     17507.0
# 354                              Burns town, Tennessee  2045      2103.0       780.0
# 355                         Cedar Hill city, Tennessee  2045       400.0       149.0
# 356                          Charlotte town, Tennessee  2045      1720.0       738.0
# 357                        Clarksville city, Tennessee  2045    218730.0     84382.0
# 358                           Columbia city, Tennessee  2045     55009.0     22151.0
# 359                         Coopertown town, Tennessee  2045      6278.0      2113.0
# 360                       Cross Plains city, Tennessee  2045      2306.0       801.0
# 361                    Cumberland City town, Tennessee  2045       421.0       188.0
# 362                            Dickson city, Tennessee  2045     19474.0      8097.0
# 363                              Dover city, Tennessee  2045      1938.0       806.0
# 364                         Eagleville city, Tennessee  2045      1818.0       675.0
# 365                               Erin city, Tennessee  2045      1421.0       604.0
# 366                           Fairview city, Tennessee  2045     31973.0     11717.0
# 367                       Forest Hills city, Tennessee  2045      6638.0      2460.0
# 368                           Franklin city, Tennessee  2045    123341.0     46792.0
# 369                           Gallatin city, Tennessee  2045     50489.0     20394.0
# 370                     Goodlettsville city, Tennessee  2045     23964.0      9995.0
# 371                         Greenbrier town, Tennessee  2045      8993.0      3393.0
# 372                     Hendersonville city, Tennessee  2045     76090.0     29763.0
# 373                   Kingston Springs town, Tennessee  2045      4370.0      1565.0
# 374                          La Vergne city, Tennessee  2045     48920.0     16197.0
# 375                            Lebanon city, Tennessee  2045     51373.0     20476.0
# 376                             McEwen city, Tennessee  2045      2085.0       825.0
# 377                       Millersville city, Tennessee  2045      9175.0      3651.0
# 378                      Mitchellville city, Tennessee  2045       289.0       111.0
# 379                       Mount Juliet city, Tennessee  2045     42938.0     16181.0
# 380                     Mount Pleasant city, Tennessee  2045      5043.0      2098.0
# 381                       Murfreesboro city, Tennessee  2045    202982.0     79953.0
# 382  Nashville-Davidson metropolitan government (ba...  2045    745720.0    319500.0
# 383                   New Johnsonville city, Tennessee  2045      2191.0       889.0
# 384                        Nolensville town, Tennessee  2045     24675.0      8554.0
# 385                           Oak Hill city, Tennessee  2045      5560.0      2144.0
# 386                             Pegram town, Tennessee  2045      4280.0      1585.0
# 387                      Pleasant View city, Tennessee  2045      6578.0      2231.0
# 388                           Portland city, Tennessee  2045     17353.0      6274.0
# 389                           Ridgetop city, Tennessee  2045      2949.0      1131.0
# 390                            Slayden town, Tennessee  2045       277.0        99.0
# 391                             Smyrna town, Tennessee  2045     58717.0     21922.0
# 392                        Spring Hill city, Tennessee  2045     54695.0     18800.0
# 393                        Springfield city, Tennessee  2045     31366.0     12633.0
# 394                    Tennessee Ridge town, Tennessee  2045      2264.0       967.0
# 395                 Thompson's Station town, Tennessee  2045     16856.0      6012.0
# 396                            Vanleer town, Tennessee  2045       453.0       172.0
# 397                          Watertown city, Tennessee  2045      2097.0       830.0
# 398                            Waverly city, Tennessee  2045      4205.0      1951.0
# 399                       Westmoreland town, Tennessee  2045      4769.0      1857.0
# 400                        White Bluff town, Tennessee  2045      4816.0      1852.0
# 401                        White House city, Tennessee  2045     20873.0      7427.0
# 402                                               GNRC  2045   3112345.0   1171266.0
# 403                                                MPO  2045   2707389.0   1014756.0
# 404                                        GNRC Region  2045   3229021.0   1216853.0

# %%
#make sure year is formatted as an integer and generate list of years and all possible time frames
data['Year'] = data['Year'].astype(int)
#create a list of years from the dataframe to pass through our "generate time frames" function to create a list of all possible time frames - need this here for later
years = list(data['Year'].unique().astype(int))
time_frames = generate_time_frames(years)

# %%
#create a multilevel column header with year and placeholder for time frames
#pivot the table and create a multiindex of year and column header
cols = list(data.columns)
cols.remove('NAME')
cols.remove('Year')
df_pivot = data.pivot_table(index = ['NAME'], columns = ['Year'], values = cols)
df_pivot.head(2)
# Out:
#                              Households                                 Population
# Year                               2017    2020    2025    2035    2045       2017    2020    2025    2035    2045
# NAME
# Adams city, Tennessee             228.0   250.0   249.0   274.0   309.0      728.0   624.0   801.0   876.0   995.0
# Ashland City town, Tennessee     2070.0  2311.0  2737.0  3428.0  4101.0     4701.0  5193.0  6315.0  7850.0  9431.0

# %%
#add a level to the multiindex to accomodate the time period metrics
df_pivot.columns = pd.MultiIndex.from_tuples([(col[0], col[1], 'None') for col in df_pivot.columns])
df_pivot.head(3)
# Out:
#                              Households                                 Population
#                                    2017    2020    2025    2035    2045       2017    2020    2025    2035    2045
#                                    None    None    None    None    None       None    None    None    None    None
# NAME
# Adams city, Tennessee             228.0   250.0   249.0   274.0   309.0      728.0   624.0   801.0   876.0   995.0
# Ashland City town, Tennessee     2070.0  2311.0  2737.0  3428.0  4101.0     4701.0  5193.0  6315.0  7850.0  9431.0
# Belle Meade city, Tennessee      1021.0  1130.0  1081.0  1114.0  1146.0     2615.0  2901.0  2790.0  2875.0  2959.0

# %%
#get a list of the varaibles to loop through by indexing into the first level only of the column headers
first_level = df_pivot.columns.get_level_values(0).unique().tolist()
# first_level.remove('NAME')
# first_level.remove('Year')
#remove percentages - don't want change metrics on them
first_level = [item for item in first_level if '%' not in item]

# %%
#pass the dataframe, the list of variables, time frames, and years through the "calculate change" function
data = calculate_changes(df_pivot, first_level, time_frames = time_frames, years = years)

# %%
#reformat and rename columns
data = data.stack([1, 1])
data = data.reset_index(drop = False)
data = data.rename(columns = {'level_1':'Year', 'level_2':'Time Frame'})

# %%
data.head()
# Out:
#                     NAME  Year Time Frame  Households  Households % Change  Households Change  Population  Population % Change  Population Change
# 0  Adams city, Tennessee  2017       None       228.0                  NaN                NaN       728.0                  NaN                NaN
# 1  Adams city, Tennessee  2020       None       250.0                  NaN                NaN       624.0                  NaN                NaN
# 2  Adams city, Tennessee  2025       None       249.0                  NaN                NaN       801.0                  NaN                NaN
# 3  Adams city, Tennessee  2035       None       274.0                  NaN                NaN       876.0                  NaN                NaN
# 4  Adams city, Tennessee  2045       None       309.0                  NaN                NaN       995.0                  NaN                NaN

# %%
#map to geoid dictionary from module and add source
data['GEO_ID'] = data['NAME'].map(geotogeoid)
data['Source'] = 'Woods & Poole 2017 Base'

# %%
#final check
data.tail()
# Out:
#                        NAME  Year Time Frame  Households  Households % Change  Households Change  Population  Population % Change  \
# 1210  Wilson Unincorporated  None  2020-2035         NaN            62.136759            16593.0         NaN            70.267586
# 1211  Wilson Unincorporated  None  2020-2045         NaN           119.124476            31811.0         NaN           130.424749
# 1212  Wilson Unincorporated  None  2025-2035         NaN            37.293886            11761.0         NaN            38.257724
# 1213  Wilson Unincorporated  None  2025-2045         NaN            85.549848            26979.0         NaN            87.105497
# 1214  Wilson Unincorporated  None  2035-2045         NaN            35.147932            15218.0         NaN            35.330954
#
#       Population Change GEO_ID                   Source
# 1210            48108.0    NaN  Woods & Poole 2017 Base
# 1211            89294.0    NaN  Woods & Poole 2017 Base
# 1212            32257.0    NaN  Woods & Poole 2017 Base
# 1213            73443.0    NaN  Woods & Poole 2017 Base
# 1214            41186.0    NaN  Woods & Poole 2017 Base

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1215 entries, 0 to 1214
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NAME                 1215 non-null   object
#  1   Year                 1215 non-null   object
#  2   Time Frame           1215 non-null   object
#  3   Households           405 non-null    float64
#  4   Households % Change  810 non-null    float64
#  5   Households Change    810 non-null    float64
#  6   Population           405 non-null    float64
#  7   Population % Change  810 non-null    float64
#  8   Population Change    810 non-null    float64
#  9   GEO_ID               1005 non-null   object
#  10  Source               1215 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 104.5+ KB

# %%
hhsuff = hhsuff.reset_index(drop = False)
popsuff = popsuff.reset_index(drop = False)
suff = hhsuff.merge(popsuff)
suff['GEO_ID'] = suff['NAME'].map(geotogeoid)
suff['Source'] = 'Woods & Poole 2017 Base'

# %%
suff.tail()
# Out:
#                            NAME  Households 2017  Households 2020  Households 2025  Households 2035  Households 2045  Population 2017  \
# 76  White Bluff town, Tennessee             1426           1597.0             1596             1725             1852             3733
# 77  White House city, Tennessee             4305           5039.0             5394             6413             7427            12392
# 78                         GNRC           711137         864517.0           845208           996443          1171266          1893650
# 79                          MPO           623540         759407.0           737550           865792          1014756          1649724
# 80                  GNRC Region           744469         907660.0           882842          1038007          1216853          1981256
#
#     Population 2020  Population 2025  Population 2035  Population 2045  Population Unnamed: 7            GEO_ID                   Source
# 76           3862.0             4163             4490             4816                    NaN  1600000US4779980  Woods & Poole 2017 Base
# 77          12982.0            15449            18177            20873                    NaN  1600000US4780200  Woods & Poole 2017 Base
# 78        2089918.0          2209363          2647991          3112345                    NaN               NaN  Woods & Poole 2017 Base
# 79        1822891.0          1922728          2303088          2707389                    NaN               NaN  Woods & Poole 2017 Base
# 80        2190892.0          2305971          2755484          3229021                    NaN               NaN  Woods & Poole 2017 Base

# %%
#export to the SQLite database
conn = sq.connect('../../Outputs/Dem_Transpo_Housing_Collection.db')
data.to_sql('WPURBANSIM_PopulationHousehold_CurrentandProjected_Annual_Change', conn, if_exists = 'replace', index = False)
suff.to_sql('WPURBANSIM_PopulationHousehold_CurrentandProjected_Annual_WideFormat', conn, if_exists = 'replace', index = False)
# Out:
# 81
